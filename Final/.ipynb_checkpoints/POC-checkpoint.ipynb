# %% [markdown]
# # Final Notebook

# %% [markdown]
# #### By Emily Cadena

# %% [markdown]
# ## Who’s Most at Risk? Social Demographics and Traffic Collisions in the City of Los Angeles

# %% [markdown]
# ### This notebook will examine the Top 15 census tracts that has the most collisions per 1,000 people and examine who is most impacted.

# %% [markdown]
# ### Data Sources & Geographic Information

# %% [markdown]
# American Community Survey (ACS) 2015-2019 (5-Year Estimates) - Hispanic or Latino by Race
# 2015 - 2019 UC Berkeley
# TIMS  2019 Census Tracts from IPUMS NHGIS

# %% [markdown]
# ### Importing libraries

# %%
# data exploration 
import pandas as pd

# merge data 
import geopandas as gpd

# basemaps
import contextily as ctx

# spatial statistics
import esda
from esda.moran import Moran, Moran_Local

import splot
from splot.esda import moran_scatterplot, plot_moran, lisa_cluster,plot_moran_simulation

import libpysal as lps  

# importing for plots and tables 
import matplotlib.pyplot as plt
import plotly.express as px

# %%
# upload acs 2015-2019 for data exploration
race = pd.read_csv('data10/race15_19.csv')

# %% [markdown]
# ### Converting Data Types

# %%
# going into the Geo_FIPS column
# leading zero is missing 
race.Geo_FIPS.head()
# Out:
# 0    6037101110
# 1    6037101122
# 2    6037101210
# 3    6037101220
# 4    6037101300
# Name: Geo_FIPS, dtype: int64

# %%
# converting FIPS, state, and county data type from integer to string to include leading zero 
race = pd.read_csv('data10/race15_19.csv',
     dtype=
                 {'Geo_FIPS': str, 
                  'Geo_STATE': str, 
                  'Geo_COUNTY': str })

# %% [markdown]
# ### Cleaning and Reorganizing the data

# %%
# find unnecessary columns with zero values 
race.columns[race.isna().all()].tolist()
# Out:
# ['Geo_US',
#  'Geo_REGION',
#  'Geo_DIVISION',
#  'Geo_STATECE',
#  'Geo_COUSUB',
#  'Geo_PLACE',
#  'Geo_PLACESE',
#  'Geo_PUMA1']

# %%
# deleting uncessary columns 
race = race.dropna(axis=1,how="all")

# %%
# keep columns
columns_to_keep = ['Geo_FIPS', 
                   'Geo_STATE', 
                   'Geo_COUNTY',
                   'Geo_TRACT',
                   'SE_B04001_001', 
                   'SE_B04001_002', 
                   'SE_B04001_003',      
                   'SE_B04001_004',       
                   'SE_B04001_005',        
                   'SE_B04001_006',       
                   'SE_B04001_007',        
                   'SE_B04001_008',       
                   'SE_B04001_009',      
                   'SE_B04001_010',      
                   'PCT_SE_B04001_002',  
                   'PCT_SE_B04001_003',
                   'PCT_SE_B04001_004',  
                   'PCT_SE_B04001_005',  
                   'PCT_SE_B04001_006',  
                   'PCT_SE_B04001_007',  
                   'PCT_SE_B04001_008',  
                   'PCT_SE_B04001_009',  
                   'PCT_SE_B04001_010']

race=race[columns_to_keep]

# %%
race.columns.to_list()
# Out:
# ['Geo_FIPS',
#  'Geo_STATE',
#  'Geo_COUNTY',
#  'Geo_TRACT',
#  'SE_B04001_001',
#  'SE_B04001_002',
#  'SE_B04001_003',
#  'SE_B04001_004',
#  'SE_B04001_005',
#  'SE_B04001_006',
#  'SE_B04001_007',
#  'SE_B04001_008',
#  'SE_B04001_009',
#  'SE_B04001_010',
#  'PCT_SE_B04001_002',
#  'PCT_SE_B04001_003',
#  'PCT_SE_B04001_004',
#  'PCT_SE_B04001_005',
#  'PCT_SE_B04001_006',
#  'PCT_SE_B04001_007',
#  'PCT_SE_B04001_008',
#  'PCT_SE_B04001_009',
#  'PCT_SE_B04001_010']

# %%
# rename columns
# % is total population XXX (ex. % Total Population: Hispanic or Latino)
race.columns = ['FIPS',
                'State',
                'County',
                'Census Tract',
                'Total Population',
                'Total Population: Not Hispanic or Latino',
                'White',
                'Black',
                'American Indian and Alaska Native Alone',
                'Asian',
                'Native Hawaiian and Other Pacific Islander Alone',
                'Some Other Race Alone',
                'Two or More Races',
                'Hispanic or Latino',
                '% Not Hispanic or Latino',
                '% White',
                '% Black',
                '% American Indian and Alaska Native Alone',
                '% Asian',
                '% Native Hawaiian and Other Pacific Islander Alone',
                '% Some Other Race Alone',
                '% Two or More Races',
                '% Hispanic or Latino']

# %%
race.head(2)
# Out:
#           FIPS State County  Census Tract  Total Population  \
# 0  06037101110    06    037        101110              4283
# 1  06037101122    06    037        101122              3405
#
#    Total Population: Not Hispanic or Latino  White  Black  \
# 0                                      3095   2616     19
# 1                                      3258   2882     74
#
#    American Indian and Alaska Native Alone  Asian  ...  Hispanic or Latino  \
# 0                                        3    331  ...                1188
# 1                                       15    220  ...                 147
#
#    % Not Hispanic or Latino  % White  % Black  \
# 0                     72.26    61.08     0.44
# 1                     95.68    84.64     2.17
#
#    % American Indian and Alaska Native Alone  % Asian  \
# 0                                       0.07     7.73
# 1                                       0.44     6.46
#
#    % Native Hawaiian and Other Pacific Islander Alone  \
# 0                                               0.07
# 1                                               0.00
#
#    % Some Other Race Alone  % Two or More Races  % Hispanic or Latino
# 0                     0.19                 2.69                 27.74
# 1                     0.00                 1.97                  4.32
#
# [2 rows x 23 columns]

# %% [markdown]
# ### Creating POC Column

# %%
#creating a new column PCT_POC - Includes % Black, % Asian, and % Hispanic and latino
race['PCT_POCv1'] = race['% Black'] + race['% Asian']+ race['% Hispanic or Latino']

# %%
# double checking PCT_POC column by creating a second column 
race['PCT_POCv2'] = None

# %%
race['PCT_POCv2'] = race['Black'] + race['Asian']+ race['Hispanic or Latino']

# %%
race['PCT_POCv2'] = race['PCT_POCv2']/race['Total Population']*100

# %%
#rename a column 
race.rename(columns={'PCT_POCv1': '% People of Color'}, inplace=True)

# %%
race.head(2)
# have practically the same result for PCT_POCv1 and PCT_POCv2
# Out:
#           FIPS State County  Census Tract  Total Population  \
# 0  06037101110    06    037        101110              4283
# 1  06037101122    06    037        101122              3405
#
#    Total Population: Not Hispanic or Latino  White  Black  \
# 0                                      3095   2616     19
# 1                                      3258   2882     74
#
#    American Indian and Alaska Native Alone  Asian  ...  % White  % Black  \
# 0                                        3    331  ...    61.08     0.44
# 1                                       15    220  ...    84.64     2.17
#
#    % American Indian and Alaska Native Alone  % Asian  \
# 0                                       0.07     7.73
# 1                                       0.44     6.46
#
#    % Native Hawaiian and Other Pacific Islander Alone  \
# 0                                               0.07
# 1                                               0.00
#
#    % Some Other Race Alone  % Two or More Races  % Hispanic or Latino  \
# 0                     0.19                 2.69                 27.74
# 1                     0.00                 1.97                  4.32
#
#    % People of Color  PCT_POCv2
# 0              35.91  35.909409
# 1              12.95  12.951542
#
# [2 rows x 25 columns]

# %% [markdown]
# ### Merge

# %%
# add city of LA census tract 
cityofla=gpd.read_file('data10/cityLA.zip')

# %%
# add a FIPS column
# creating a new column so that I can merge the shapefile and census tracts 

cityofla['FIPS'] = '06' + '037' + cityofla['TRACTCE']

# %%
# need to merge by creating a new dataframe
la_race =cityofla.merge(race,on="FIPS")

# %%
# find the sum for each race and ethncity 
print(la_race['White'].sum())
print(la_race['Black'].sum())
print(la_race['Asian'].sum())
print(la_race['Hispanic or Latino'].sum())
# Out:
# 1378808
# 430875
# 543767
# 2220293

# %%
#racebar1 only includes data for reach race and ethnicity in the City of LA  

racebar1 = racebar1=pd.DataFrame({'Race and Ethnicity':['White', 'Black', 'Asian', 'Hispanic or Latino'], 
                   'Population Count':[1378808, 430875, 543767, 2220293], 
                   'Color':['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728']})

# %%
# creating a bar chart of race and ethnicty in LA County using plotly 
fig = px.bar(racebar1, 
       x='Race and Ethnicity',
       y='Population Count',
       title='Race & Ethnicity in the City of Los Angeles, 2019',
       color='Race and Ethnicity', 
       color_discrete_sequence=racebar1['Color'])
    
# get rid of white lines inside the bars
fig.update_traces(marker_line_width=0)

fig.update_layout(xaxis_tickangle=0, 
                  plot_bgcolor='rgba(0,0,0,0)',
                  paper_bgcolor='rgba(0,0,0,0)'
                 )
 
# show the figure
fig.show()
# Out:
# <div>                            <div id="bf884e78-ff5e-4d92-94fd-5c3e91db2655" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bf884e78-ff5e-4d92-94fd-5c3e91db2655")) {                    Plotly.newPlot(                        "bf884e78-ff5e-4d92-94fd-5c3e91db2655",                        [{"alignmentgroup":"True","hovertemplate":"Race and Ethnicity=%{x}\u003cbr\u003ePopulation Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"White","marker":{"color":"#1f77b4","pattern":{"shape":""},"line":{"width":0}},"name":"White","offsetgroup":"White","orientation":"v","showlegend":true,"textposition":"auto","x":["White"],"xaxis":"x","y":[1378808],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Race and Ethnicity=%{x}\u003cbr\u003ePopulation Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Black","marker":{"color":"#ff7f0e","pattern":{"shape":""},"line":{"width":0}},"name":"Black","offsetgroup":"Black","orientation":"v","showlegend":true,"textposition":"auto","x":["Black"],"xaxis":"x","y":[430875],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Race and Ethnicity=%{x}\u003cbr\u003ePopulation Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Asian","marker":{"color":"#2ca02c","pattern":{"shape":""},"line":{"width":0}},"name":"Asian","offsetgroup":"Asian","orientation":"v","showlegend":true,"textposition":"auto","x":["Asian"],"xaxis":"x","y":[543767],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Race and Ethnicity=%{x}\u003cbr\u003ePopulation Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Hispanic or Latino","marker":{"color":"#d62728","pattern":{"shape":""},"line":{"width":0}},"name":"Hispanic or Latino","offsetgroup":"Hispanic or Latino","orientation":"v","showlegend":true,"textposition":"auto","x":["Hispanic or Latino"],"xaxis":"x","y":[2220293],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#460 ...

# %% [markdown]
# ### Function and loop for Race & Ethnicity

# %%
# Created a function here because eventually, I want to loop through VARIOUS columns instead of unique values within ONE Column 

def plot_maps(data, columns, title_prefix):  

     for column in columns:
        fig, ax = plt.subplots(1, 1, figsize=(12, 12))
        la_race.plot(ax=ax,column=column,legend=True,cmap='GnBu',
             legend_kwds={"label": "Population (%)", "orientation": "vertical"})
      
        ax.axis('off')
        ax.set_title (f" {column} {title_prefix}")

        ax.set_aspect('equal')

        filename = f"{save_prefix}_{column}.png"
        plt.savefig(filename)
        plt.close()

# %%
#columns to plot 
race_map = ['% White', '% Black', '% Asian', '% Hispanic or Latino', '% People of Color', 'PCT_POCv2']
save_prefix = "population_los_angeles_2019"

# %%
# loop!
plot_maps(la_race, race_map, "Population in the City of Los Angeles, 2019")

# %%
race.head(2)
# Out:
#           FIPS State County  Census Tract  Total Population  \
# 0  06037101110    06    037        101110              4283
# 1  06037101122    06    037        101122              3405
#
#    Total Population: Not Hispanic or Latino  White  Black  \
# 0                                      3095   2616     19
# 1                                      3258   2882     74
#
#    American Indian and Alaska Native Alone  Asian  ...  % White  % Black  \
# 0                                        3    331  ...    61.08     0.44
# 1                                       15    220  ...    84.64     2.17
#
#    % American Indian and Alaska Native Alone  % Asian  \
# 0                                       0.07     7.73
# 1                                       0.44     6.46
#
#    % Native Hawaiian and Other Pacific Islander Alone  \
# 0                                               0.07
# 1                                               0.00
#
#    % Some Other Race Alone  % Two or More Races  % Hispanic or Latino  \
# 0                     0.19                 2.69                 27.74
# 1                     0.00                 1.97                  4.32
#
#    % People of Color  PCT_POCv2
# 0              35.91  35.909409
# 1              12.95  12.951542
#
# [2 rows x 25 columns]

# %% [markdown]
# ### Examining TIMS data

# %%
import matplotlib.pyplot as plt
tims = pd.read_csv('data10/pedbike_tims.csv')
# Out:
# /tmp/ipykernel_711/3595572550.py:2: DtypeWarning:
#
# Columns (6,14) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
tims.head(2)
# Out:
#    CASE_ID  ACCIDENT_YEAR   PROC_DATE  JURIS COLLISION_DATE  COLLISION_TIME  \
# 0  6292270           2015  2015-06-11   1942     2015-05-25            2145
# 1  6292319           2015  2017-04-25   9590     2015-02-23             434
#
#   OFFICER_ID REPORTING_DISTRICT  DAY_OF_WEEK  CHP_SHIFT  ...  COUNT_MC_KILLED  \
# 0      38124               1375            1          5  ...                0
# 1      20617                NaN            1          3  ...                0
#
#    COUNT_MC_INJURED  PRIMARY_RAMP  SECONDARY_RAMP  LATITUDE  LONGITUDE  \
# 0                 0            -               -        NaN        NaN
# 1                 0            -               -   34.03387 -118.22002
#
#         COUNTY         CITY     POINT_X    POINT_Y
# 0  LOS ANGELES  LOS ANGELES -118.252130  33.992984
# 1  LOS ANGELES  LOS ANGELES -118.220705  34.034132
#
# [2 rows x 80 columns]

# %%
# need to plot, so get
tims = gpd.GeoDataFrame(tims, 
                         crs ='EPSG:4326', 
                         geometry=gpd.points_from_xy(tims.POINT_X, tims.POINT_Y))

# %%
# checking tims projection
print("tims", tims.crs)
# Out:
# tims EPSG:4326

# %%
# checking tims projection
print("la_race", la_race.crs)
# Out:
# la_race PROJCS["USA_Contiguous_Albers_Equal_Area_Conic",GEOGCS["NAD83",DATUM["North_American_Datum_1983",SPHEROID["GRS 1980",6378137,298.257222101,AUTHORITY["EPSG","7019"]],AUTHORITY["EPSG","6269"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4269"]],PROJECTION["Albers_Conic_Equal_Area"],PARAMETER["latitude_of_center",37.5],PARAMETER["longitude_of_center",-96],PARAMETER["standard_parallel_1",29.5],PARAMETER["standard_parallel_2",45.5],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH],AUTHORITY["ESRI","102003"]]

# %%
# checking tims projection
print("la_race", la_race.crs)
la_race = la_race.to_crs(epsg=4326)
# Out:
# la_race PROJCS["USA_Contiguous_Albers_Equal_Area_Conic",GEOGCS["NAD83",DATUM["North_American_Datum_1983",SPHEROID["GRS 1980",6378137,298.257222101,AUTHORITY["EPSG","7019"]],AUTHORITY["EPSG","6269"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4269"]],PROJECTION["Albers_Conic_Equal_Area"],PARAMETER["latitude_of_center",37.5],PARAMETER["longitude_of_center",-96],PARAMETER["standard_parallel_1",29.5],PARAMETER["standard_parallel_2",45.5],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH],AUTHORITY["ESRI","102003"]]

# %%
tims.plot()
# Out:
# <Axes: >

# %%
tims = tims.dropna(subset=['geometry'])

# %%
tims.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 25059 entries, 0 to 25058
# Data columns (total 81 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   CASE_ID                  25059 non-null  int64
#  1   ACCIDENT_YEAR            25059 non-null  int64
#  2   PROC_DATE                25059 non-null  object
#  3   JURIS                    25059 non-null  int64
#  4   COLLISION_DATE           25059 non-null  object
#  5   COLLISION_TIME           25059 non-null  int64
#  6   OFFICER_ID               25035 non-null  object
#  7   REPORTING_DISTRICT       24440 non-null  object
#  8   DAY_OF_WEEK              25059 non-null  int64
#  9   CHP_SHIFT                25059 non-null  int64
#  10  POPULATION               25059 non-null  int64
#  11  CNTY_CITY_LOC            25059 non-null  int64
#  12  SPECIAL_COND             25059 non-null  int64
#  13  BEAT_TYPE                25059 non-null  int64
#  14  CHP_BEAT_TYPE            25059 non-null  object
#  15  CITY_DIVISION_LAPD       19834 non-null  object
#  16  CHP_BEAT_CLASS           25059 non-null  int64
#  17  BEAT_NUMBER              24642 non-null  object
#  18  PRIMARY_RD               25059 non-null  object
#  19  SECONDARY_RD             25059 non-null  object
#  20  DISTANCE                 25059 non-null  float64
#  21  DIRECTION                14750 non-null  object
#  22  INTERSECTION             25059 non-null  object
#  23  WEATHER_1                25059 non-null  object
#  24  WEATHER_2                25059 non-null  object
#  25  STATE_HWY_IND            25056 non-null  object
#  26  CALTRANS_COUNTY          435 non-null    object
#  27  CALTRANS_DISTRICT        435 non-null    float64
#  28  STATE_ROUTE              684 non-null    float64
#  29  ROUTE_SUFFIX             435 non-null    object
#  30  POSTMILE_PREFIX          435 non-null    object
#  31  POSTMILE                 435 non-null    float64
#  32  LOCATION_TYPE            514 non-null    object
#  33  RAMP_INTERSECTION        435 non-null    object
#  34  SIDE_OF_HWY              680 non-null    object
#  35  TOW_AWAY                 24839 non-null  object
#  36  COLLISION_SEVERITY       25059 non-null  int64
#  37  NUMBER_KILLED            25059 non-null  int64
#  38  NUMBER_INJURED           25059 non-null  int64
#  39  PARTY_COUNT              25059 non-null  int64
#  40  PRIMARY_COLL_FACTOR      25059 non-null  object
#  41  PCF_CODE_OF_VIOL         25059 non-null  object
#  42  PCF_VIOL_CATEGORY        25059 non-null  object
#  43  PCF_VIOLATION            23538 non-null  float64
#  44  PCF_VIOL_SUBSECTION      17151 non-null  object
#  45  HIT_AND_RUN              25059 non-null  object
#  46  TYPE_OF_COLLISION        25059 non-null  object
#  47  MVIW                     25059 non-null  object
#  48  PED_ACTION               25059 non-null  object
#  49  ROAD_SURFACE             25059 non-null  object
#  50  ROAD_COND_1              25059 non-null  object
#  51  ROAD_COND_2              25059 non-null  object
#  52  LIGHTING                 25059 non-null  object
#  53  CONTROL_DEVICE           25059 non-null  object
#  54  CHP_ROAD_TYPE            25059 non-null  int64
#  55  PEDESTRIAN_ACCIDENT      15600 non-null  object
#  56  BICYCLE_ACCIDENT         9569 non-null   object
#  57  MOTORCYCLE_ACCIDENT      168 non-null    object
#  58  TRUCK_ACCIDENT           253 non-null    object
#  59  NOT_PRIVATE_PROPERTY     25059 non-null  object
#  60  ALCOHOL_INVOLVED         2065 non-null   object
#  61  STWD_VEHTYPE_AT_FAULT    25059 non-null  object
#  62  CHP_VEHTYPE_AT_FAULT     24405 non-null  object
#  63  COUNT_SEVERE_INJ         25059 non-null  int64
#  64  COUNT_VISIBLE_INJ        25059 non-null  int64
#  65  COUNT_COMPLAINT_PAIN     25059 non-null  int64
#  66  COUNT_PED_KILLED         25059 non-null  int64
#  67  COUNT_PED_INJURED        25059 non-null  int64
#  68  COUNT_BICYCLIST_KILLED   25059 non-null  int64
#  69  COUNT_BICYCLIST_INJURED  25059 non-null  int64
#  70  COUNT_MC_KILLED          25059 non-null  int64
#  71  COUNT_MC_INJURED         25059 non-null  int64
#  72  PRIMARY_RAMP             25059 non-null  object
#  73  SECONDARY_RAMP           25059 non-null  object
#  74  LATITUDE                 359 non-null    float64
#  75  LONGITUDE                359 non-null    float64
#  76  COUNTY                   25059 non-null  object
#  77  CITY                     25059 non-null  object
#  78  POINT_X                  25059 non-null  float64
#  79  POINT_Y                  25059 non-null  float64
#  80  geometry                 25059 non-null  geometry
# dtypes: float64(9), geometry(1), int64(25), object(46)
# memory usage: 15.5+ MB

# %%
#spatial join between collisions and city of LA 
boundary = gpd.read_file("data10/City_Boundary.geojson") 
tims = gpd.sjoin(tims, boundary, predicate="within", how="inner")

# %%
#getting ped points 
ped = tims[tims["PEDESTRIAN_ACCIDENT"] == 'Y']
ped.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 15457 entries, 1 to 25058
# Data columns (total 84 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   CASE_ID                  15457 non-null  int64
#  1   ACCIDENT_YEAR            15457 non-null  int64
#  2   PROC_DATE                15457 non-null  object
#  3   JURIS                    15457 non-null  int64
#  4   COLLISION_DATE           15457 non-null  object
#  5   COLLISION_TIME           15457 non-null  int64
#  6   OFFICER_ID               15444 non-null  object
#  7   REPORTING_DISTRICT       15043 non-null  object
#  8   DAY_OF_WEEK              15457 non-null  int64
#  9   CHP_SHIFT                15457 non-null  int64
#  10  POPULATION               15457 non-null  int64
#  11  CNTY_CITY_LOC            15457 non-null  int64
#  12  SPECIAL_COND             15457 non-null  int64
#  13  BEAT_TYPE                15457 non-null  int64
#  14  CHP_BEAT_TYPE            15457 non-null  object
#  15  CITY_DIVISION_LAPD       12205 non-null  object
#  16  CHP_BEAT_CLASS           15457 non-null  int64
#  17  BEAT_NUMBER              15205 non-null  object
#  18  PRIMARY_RD               15457 non-null  object
#  19  SECONDARY_RD             15457 non-null  object
#  20  DISTANCE                 15457 non-null  float64
#  21  DIRECTION                9303 non-null   object
#  22  INTERSECTION             15457 non-null  object
#  23  WEATHER_1                15457 non-null  object
#  24  WEATHER_2                15457 non-null  object
#  25  STATE_HWY_IND            15456 non-null  object
#  26  CALTRANS_COUNTY          221 non-null    object
#  27  CALTRANS_DISTRICT        221 non-null    float64
#  28  STATE_ROUTE              437 non-null    float64
#  29  ROUTE_SUFFIX             221 non-null    object
#  30  POSTMILE_PREFIX          221 non-null    object
#  31  POSTMILE                 221 non-null    float64
#  32  LOCATION_TYPE            276 non-null    object
#  33  RAMP_INTERSECTION        221 non-null    object
#  34  SIDE_OF_HWY              434 non-null    object
#  35  TOW_AWAY                 15317 non-null  object
#  36  COLLISION_SEVERITY       15457 non-null  int64
#  37  NUMBER_KILLED            15457 non-null  int64
#  38  NUMBER_INJURED           15457 non-null  int64
#  39  PARTY_COUNT              15457 non-null  int64
#  40  PRIMARY_COLL_FACTOR      15457 non-null  object
#  41  PCF_CODE_OF_VIOL         15457 non-null  object
#  42  PCF_VIOL_CATEGORY        15457 non-null  object
#  43  PCF_VIOLATION            14574 non-null  float64
#  44  PCF_VIOL_SUBSECTION      11236 non-null  object
#  45  HIT_AND_RUN              15457 non-null  object
#  46  TYPE_OF_COLLISION        15457 non-null  object
#  47  MVIW                     15457 non-null  object
#  48  PED_ACTION               15457 non-null  object
#  49  ROAD_SURFACE             15457 non-null  object
#  50  ROAD_COND_1              15457 non-null  object
#  51  ROAD_COND_2              15457 non-null  object
#  52  LIGHTING                 15457 non-null  object
#  53  CONTROL_DEVICE           15457 non-null  object
#  54  CHP_ROAD_TYPE            15457 non-null  int64
#  55  PEDESTRIAN_ACCIDENT      15457 non-null  object
#  56  BICYCLE_ACCIDENT         110 non-null    object
#  57  MOTORCYCLE_ACCIDENT      112 non-null    object
#  58  TRUCK_ACCIDENT           164 non-null    object
#  59  NOT_PRIVATE_PROPERTY     15457 non-null  object
#  60  ALCOHOL_INVOLVED         1574 non-null   object
#  61  STWD_VEHTYPE_AT_FAULT    15457 non-null  object
#  62  CHP_VEHTYPE_AT_FAULT     15038 non-null  object
#  63  COUNT_SEVERE_INJ         15457 non-null  int64
#  64  COUNT_VISIBLE_INJ        15457 non-null  int64
#  65  COUNT_COMPLAINT_PAIN     15457 non-null  int64
#  66  COUNT_PED_KILLED         15457 non-null  int64
#  67  COUNT_PED_INJURED        15457 non-null  int64
#  68  COUNT_BICYCLIST_KILLED   15457 non-null  int64
#  69  COUNT_BICYCLIST_INJURED  15457 non-null  int64
#  70  COUNT_MC_KILLED          15457 non-null  int64
#  71  COUNT_MC_INJURED         15457 non-null  int64
#  72  PRIMARY_RAMP             15457 non-null  object
#  73  SECONDARY_RAMP           15457 non-null  object
#  74  LATITUDE                 271 non-null    float64
#  75  LONGITUDE                271 non-null    float64
#  76  COUNTY                   15457 non-null  object
#  77  CITY_left                15457 non-null  object
#  78  POINT_X                  15457 non-null  float64
#  79  POINT_Y                  15457 non-null  float64
#  80  geometry                 15457 non-null  geometry
#  81  index_right              15457 non-null  int64
#  82  OBJECTID                 15457 non-null  int32
#  83  CITY_right               15457 non-null  object
# dtypes: float64(9), geometry(1), int32(1), int64(26), object(47)
# memory usage: 10.0+ MB

# %%
#getting bike points 
bike = tims[tims["BICYCLE_ACCIDENT"] == 'Y']
bike.head(2)
# Out:
#    CASE_ID  ACCIDENT_YEAR   PROC_DATE  JURIS COLLISION_DATE  COLLISION_TIME  \
# 0  6292270           2015  2015-06-11   1942     2015-05-25            2145
# 4  6292461           2015  2017-04-06   1942     2015-07-07            1840
#
#   OFFICER_ID REPORTING_DISTRICT  DAY_OF_WEEK  CHP_SHIFT  ...  LATITUDE  \
# 0      38124               1375            1          5  ...       NaN
# 4      36607               0526            2          5  ...       NaN
#
#    LONGITUDE       COUNTY    CITY_left    POINT_X    POINT_Y  \
# 0        NaN  LOS ANGELES  LOS ANGELES -118.25213  33.992984
# 4        NaN  LOS ANGELES  LOS ANGELES -118.26245  33.779980
#
#                       geometry index_right OBJECTID CITY_right
# 0  POINT (-118.25213 33.99298)           0        1         IN
# 4  POINT (-118.26245 33.77998)           0        1         IN
#
# [2 rows x 84 columns]

# %%
def plot_maps2(data, columns, title_prefix):  

     for column in columns:
        fig, ax = plt.subplots(figsize=(12, 12))
        la_race.plot(ax=ax,column=column,legend=True,cmap='GnBu',
             legend_kwds={"label": "Population (%)", "orientation": "vertical"})

        ped.plot(ax=ax, color='purple', markersize=1, alpha=0.6, label='Pedestrian Collisions')
        bike.plot(ax=ax, color='red', markersize=1, alpha=0.6, label='Bicycle Collisions')
        ax.legend(fontsize=12, loc="lower left", markerscale=8., bbox_to_anchor=(0.05, 0.05)) 

        ax.set_xlim(la_race.total_bounds[[0, 2]])  
        ax.set_ylim(la_race.total_bounds[[1, 3]])   
         
        ax.axis('off')
        ax.set_title (f" {title_prefix} {column} Population in the City of Los Angeles")

        filename = f"{save_prefix}_{column}.png"
        plt.savefig(filename)
        plt.close()

# %%
# columns to plot
tims_map = ['% White', '% Black', '% Asian', '% Hispanic or Latino', '% People of Color']
save_prefix = "tims_bike_ped"

# %%
plot_maps2(la_race, tims_map, 'TIMS Pedestrian and Bicycle Collisions and')

# %% [markdown]
# ### Next Step
# 1. Race and TIMS outlines the Top 15 census tracts
# 2. Table with cenus tracts and variable (maybe a spatial join  and do the explore function)
# 3. Consider w8 or w9 spatial daata
# 4. question for gema - include your map in the analysis (spatial lag etc)
# 5. do the housing exercise but with the top 1, 3, or 5 census tracts as well!! for my paper?
# 6. Consider making charts for different accidents etc
