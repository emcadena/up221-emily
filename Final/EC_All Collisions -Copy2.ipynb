# %% [markdown]
# # Group Assignment #4
# ### Author: Gema Martinez
#
# ## Who’s Most at Risk? Social Demographics and Traffic Collisions in the City of Los Angeles
# This notebook examines the Spatial Autocorrelation Analysis of fatalities (bike and pedestrians) in the City of Los Angeles from 2015-2019 using UC Berkeley's Transportation Injury Mapping System (TIMS) data.
#
# ## Data Sources & Geographic Information
# 2019 Census Tracts from IPUMS NHGIS (At the time, we could not download the TIGER/Shapefile due to federal government actions).
#
# 2015 - 2019 UC Berkeley - TIMS

# %%
# to read and wrangle data
import pandas as pd

# to create spatial data
import geopandas as gpd

# for basemaps
import contextily as ctx

# For spatial statistics
import esda
from esda.moran import Moran, Moran_Local

import splot
from splot.esda import moran_scatterplot, plot_moran, lisa_cluster,plot_moran_simulation

import libpysal as lps

# Graphics
import matplotlib.pyplot as plt
import plotly.express as px

# %%
# importing census tracts
la_tracts = gpd.read_file('Data/cityLA.zip')

# %%
# our zip file does not include total population needed for future analysis 
# upload acs 2015-2019 data 
income = pd.read_csv('Data/R13808337_SL140.csv')

# %%
#converting FIPS, STATE, and COUNTY from integer to string & reintegrate leading zero
income = pd.read_csv(
    'Data/R13808337_SL140.csv',
    dtype=
    {
        'Geo_FIPS':str,
        'Geo_STATE':str,
        'Geo_COUNTY': str
    }
)

# %%
#refining data to keep only necessary columns
columns_to_keep = ['Geo_FIPS', 
                   'Geo_STATE', 
                   'Geo_COUNTY',
                   'SE_A14006_001']

income = income[columns_to_keep]

# %%
#remnaing columns
income.columns = ['FIPS',
                'State',
                'County',
                'Median Income']

# %%
#importing total population csv from ACS 2015-2019 to include in median income dataframe
total_population = pd.read_csv('Data/Total Population.csv')

# %%
#converting FIPS, STATE, and COUNTY from integer to string & reintegrate leading zero
total_population = pd.read_csv(
    'Data/Total Population.csv',
    dtype=
    {
        'Geo_FIPS':str,
        'Geo_STATE':str,
        'Geo_COUNTY': str,
        'SE_B04001_001': str
    }
)

# %%
#cleaning total pop data
columns_to_keep_pop = ['Geo_FIPS', 
                   'Geo_STATE', 
                   'Geo_COUNTY',
                   'SE_B04001_001']

total_population = total_population[columns_to_keep_pop]

# %%
#renaming columns
total_population.columns = ['FIPS',
                'State',
                'County',
                'Total Population']

# %%
#checking dataframe
total_population.head(2)
# Out:
#           FIPS State County Total Population
# 0  06037101110    06    037             4283
# 1  06037101122    06    037             3405

# %%
#merging income and total population
income_pop = income.merge(total_population, on="FIPS")

# %%
#checking that both dataframes merged together
income_pop.head(2)
# Out:
#           FIPS State_x County_x  Median Income State_y County_y  \
# 0  06037101110      06      037        63534.0      06      037
# 1  06037101122      06      037        90389.0      06      037
#
#   Total Population
# 0             4283
# 1             3405

# %%
# creating new FIPS column to prepare census tracts dataframe for mergining
la_tracts['FIPS'] = '06' + '037' + la_tracts['TRACTCE']

# %%
# merging census tracts and total population 
la_city = la_tracts.merge(total_population, on="FIPS")

# %%
#checking that data merged
la_city.head(2)
# Out:
#           GISJOIN STATEFP COUNTYFP TRACTCE        GEOID     NAME  \
# 0  G0600370101110      06      037  101110  06037101110  1011.10
# 1  G0600370101122      06      037  101122  06037101122  1011.22
#
#                NAMELSAD  MTFCC FUNCSTAT      ALAND  ...     INTPTLAT  \
# 0  Census Tract 1011.10  G5020        S  1142401.0  ...  +34.2594737
# 1  Census Tract 1011.22  G5020        S  2644045.0  ...  +34.2677213
#
#        INTPTLON   Shape_Leng   Shape_Le_1    Shape_Area  \
# 0  -118.2929869  4585.520052  4585.520052  1.142400e+06
# 1  -118.2901465  9652.233049  9652.233049  2.644046e+06
#
#                                             geometry         FIPS State  \
# 0  POLYGON ((-2019033.589 -124429.155, -2018948.5...  06037101110    06
# 1  POLYGON ((-2017297.948 -125225.326, -2017305.0...  06037101122    06
#
#   County Total Population
# 0    037             4283
# 1    037             3405
#
# [2 rows x 21 columns]

# %%
#cleaning the data to only include necessary columns 
columns_to_keep_la = ['FIPS', 
                   'Total Population', 
                   'geometry']

la_city = la_city[columns_to_keep_la]

# %%
# identifying total population row to delete; there is no total population column 
la_city.tail()
# Out:
#              FIPS Total Population  \
# 1163  06037980026               26
# 1164  06037980028                0
# 1165  06037980030                0
# 1166  06037980031             1175
# 1167  06037980033               16
#
#                                                geometry
# 1163  POLYGON ((-2017734.652 -121289.969, -2017604.1...
# 1164  POLYGON ((-2037371.498 -155528.944, -2037368.6...
# 1165  POLYGON ((-2039470.503 -159401.276, -2039585.4...
# 1166  MULTIPOLYGON (((-2027306.945 -179844.798, -202...
# 1167  MULTIPOLYGON (((-2027800.331 -180973.621, -202...

# %%
# modifuing total population to numerical values to fix sorting issue (the column was not sorting)
la_city['Total Population'] = pd.to_numeric(la_city['Total Population'], errors='coerce')
la_city.sort_values(by='Total Population', ascending=True).head(20)
# Out:
#              FIPS  Total Population  \
# 1165  06037980030                 0
# 1164  06037980028                 0
# 1008  06037320000                 0
# 1149  06037980002                 0
# 1158  06037980020                 0
# 1160  06037980022                 0
# 1161  06037980023                 0
# 1154  06037980013                 0
# 1150  06037980005                 0
# 1148  06037980001                 0
# 1152  06037980009                 5
# 1155  06037980014                 9
# 1167  06037980033                16
# 1163  06037980026                26
# 1159  06037980021                33
# 1032  06037532400                45
# 1151  06037980008                68
# 1146  06037930101                90
# 1065  06037575500                93
# 1153  06037980010                95
#
#                                                geometry
# 1165  POLYGON ((-2039470.503 -159401.276, -2039585.4...
# 1164  POLYGON ((-2037371.498 -155528.944, -2037368.6...
# 1008  MULTIPOLYGON (((-2026987.276 -137679.181, -202...
# 1149  MULTIPOLYGON (((-2025190.604 -177036.987, -202...
# 1158  POLYGON ((-2019136.183 -127669.077, -2019102.7...
# 1160  POLYGON ((-2034697.534 -114703.299, -2034687.1...
# 1161  POLYGON ((-2047272.84 -120824.771, -2047312.73...
# 1154  MULTIPOLYGON (((-2034925.473 -159035.208, -203...
# 1150  POLYGON ((-2030557.304 -168200.728, -2030641.3...
# 1148  MULTIPOLYGON (((-2026441.139 -130545.925, -202...
# 1152  POLYGON ((-2022567.042 -135317.48, -2022521.63...
# 1155  POLYGON ((-2023897.332 -173566.566, -2023897.0...
# 1167  MULTIPOLYGON (((-2027800.331 -180973.621, -202...
# 1163  POLYGON ((-2017734.652 -121289.969, -2017604.1...
# 1159  POLYGON ((-2025428.836 -121670.065, -2025123.7...
# 1032  MULTIPOLYGON (((-2016109.903 -153887.653, -201...
# 1151  POLYGON ((-2037999.512 -124659.921, -2037596.7...
# 1146  MULTIPOLYGON (((-2013586.944 -124850.593, -201...
# 1065  MULTIPOLYGON (((-2024641.672 -178266.284, -202...
# 1153  POLYGON ((-2018570.594 -143801.843, -2018563.2...

# %%
# deleting entries where the total population is less than 100
la_city = la_city[la_city['Total Population']>100]

# %%
# upload crash data 
# use pandas since we do not have geometry data 
collisions = pd.read_csv('Data/tims_crashes.csv')
# Out:
# /tmp/ipykernel_642/3726749257.py:3: DtypeWarning: Columns (6,7,14,26,29,30,33,42) have mixed types. Specify dtype option on import or set low_memory=False.
#   collisions = pd.read_csv('Data/tims_crashes.csv')

# %%
collisions.head(10)
# Out:
#    CASE_ID  ACCIDENT_YEAR   PROC_DATE  JURIS COLLISION_DATE  COLLISION_TIME  \
# 0  6292153           2015  2017-04-21   9590     2015-02-15             930
# 1  6292272           2015  2017-04-14   9565     2015-01-23               5
# 2  6292319           2015  2017-04-25   9590     2015-02-23             434
# 3  6292390           2015  2016-04-27   9590     2015-03-28             225
# 4  6292415           2015  2017-05-09   1942     2015-05-01            2040
# 5  6292461           2015  2017-04-06   1942     2015-07-07            1840
# 6  6292464           2015  2015-08-05   1942     2015-07-13            1450
# 7  6292536           2015  2015-08-28   1942     2015-04-17            2010
# 8  6292567           2015  2015-09-02   1942     2015-06-15            1445
# 9  6292605           2015  2017-03-29   9575     2015-07-30            1615
#
#   OFFICER_ID REPORTING_DISTRICT  DAY_OF_WEEK  CHP_SHIFT  ...  COUNT_MC_KILLED  \
# 0      20436                NaN            7          1  ...                1
# 1      20209                NaN            5          3  ...                1
# 2      20617                NaN            1          3  ...                0
# 3      20753                NaN            6          3  ...                0
# 4      25495               0774            5          5  ...                0
# 5      36607               0526            2          5  ...                0
# 6      36553               1472            1          5  ...                1
# 7      36752               1215            5          5  ...                0
# 8      36754               1269            1          5  ...                0
# 9      15935                NaN            4          2  ...                0
#
#    COUNT_MC_INJURED  PRIMARY_RAMP  SECONDARY_RAMP  LATITUDE  LONGITUDE  \
# 0                 0            -               -   34.02729 -118.21038
# 1                 0            -               -   33.98707 -118.39974
# 2                 0            -               -   34.03387 -118.22002
# 3                 0            -               -   34.03686 -118.29422
# 4                 0            -               -        NaN        NaN
# 5                 0            -               -        NaN        NaN
# 6                 0            -               -        NaN        NaN
# 7                 0            -               -        NaN        NaN
# 8                 0            -               -        NaN        NaN
# 9                 0            -               -   34.24982 -118.32258
#
#         COUNTY         CITY     POINT_X    POINT_Y
# 0  LOS ANGELES  LOS ANGELES -118.216215  34.029824
# 1  LOS ANGELES  LOS ANGELES -118.395973  33.983551
# 2  LOS ANGELES  LOS ANGELES -118.220705  34.034132
# 3  LOS ANGELES  LOS ANGELES -118.292476  34.036850
# 4  LOS ANGELES  LOS ANGELES -118.348620  34.040610
# 5  LOS ANGELES  LOS ANGELES -118.262450  33.779980
# 6  LOS ANGELES  LOS ANGELES -118.439230  33.968290
# 7  LOS ANGELES  LOS ANGELES -118.300210  33.990973
# 8  LOS ANGELES  LOS ANGELES -118.262980  33.964670
# 9  LOS ANGELES  LOS ANGELES -118.322731  34.250714
#
# [10 rows x 80 columns]

# %%
# convert data to geodataframe to plot 
collisions = gpd.GeoDataFrame(collisions, 
                         crs ='EPSG:4326', 
                         geometry=gpd.points_from_xy(collisions.POINT_X, collisions.POINT_Y))

# %%
# calculating the bounds for crash data 
# purpose - we want to zoom into the crash layer and NOT census tracts 
minx, miny, maxx, maxy = collisions.geometry.total_bounds
print(minx)
print(maxx)
print(miny)
print(maxy)
# Out:
# -118.80766778
# -117.82311248779295
# 33.7066764831543
# 34.7039263

# %%
#joining census tracrts and pedestrian collisions
collisions = collisions.to_crs(epsg=3857)
la_city = la_city.to_crs(epsg=3857)
join = gpd.sjoin(la_city, collisions, how='left')

# %%
join.head(5)
# Out:
#           FIPS  Total Population  \
# 0  06037101110              4283
# 0  06037101110              4283
# 0  06037101110              4283
# 1  06037101122              3405
# 2  06037101210              6347
#
#                                             geometry  index_right    CASE_ID  \
# 0  POLYGON ((-13168864.246 4064201.311, -13168757...       1070.0  7175207.0
# 0  POLYGON ((-13168864.246 4064201.311, -13168757...       2013.0  7190029.0
# 0  POLYGON ((-13168864.246 4064201.311, -13168757...       3790.0  8675304.0
# 1  POLYGON ((-13166582.527 4063754.258, -13166586...       1581.0  8071532.0
# 2  POLYGON ((-13167528.967 4063214.44, -13167528....       6399.0  8608664.0
#
#    ACCIDENT_YEAR   PROC_DATE   JURIS COLLISION_DATE  COLLISION_TIME  ...  \
# 0         2016.0  2016-02-04  1942.0     2016-01-04          1435.0  ...
# 0         2016.0  2016-02-23  1942.0     2016-02-10          1325.0  ...
# 0         2018.0  2018-10-04  1942.0     2018-08-09          1630.0  ...
# 1         2016.0  2016-07-08  1942.0     2016-05-19          1630.0  ...
# 2         2018.0  2018-05-02  1942.0     2018-04-09          1600.0  ...
#
#   COUNT_MC_KILLED COUNT_MC_INJURED  PRIMARY_RAMP  SECONDARY_RAMP  LATITUDE  \
# 0             0.0              0.0            -               -        NaN
# 0             0.0              0.0            -               -        NaN
# 0             0.0              0.0            -               -        NaN
# 1             0.0              1.0            -               -        NaN
# 2             0.0              0.0            -               -        NaN
#
#    LONGITUDE       COUNTY         CITY     POINT_X    POINT_Y
# 0        NaN  LOS ANGELES  LOS ANGELES -118.291050  34.255940
# 0        NaN  LOS ANGELES  LOS ANGELES -118.293208  34.256515
# 0        NaN  LOS ANGELES  LOS ANGELES -118.294693  34.259571
# 1        NaN  LOS ANGELES  LOS ANGELES -118.284510  34.255890
# 2        NaN  LOS ANGELES  LOS ANGELES -118.297951  34.254551
#
# [5 rows x 84 columns]

# %%
# creating new dataframe for collision by census tract
crash_by_cs = join.FIPS.value_counts().rename_axis('FIPS').reset_index(name='Total Collision Count')
crash_by_cs
# Out:
#              FIPS  Total Collision Count
# 0     06037226002                     72
# 1     06037980024                     67
# 2     06037241202                     47
# 3     06037106510                     38
# 4     06037241001                     34
# ...           ...                    ...
# 1143  06037275101                      1
# 1144  06037194300                      1
# 1145  06037199300                      1
# 1146  06037199202                      1
# 1147  06037191420                      1
#
# [1148 rows x 2 columns]

# %%
# these are the census tracts with the most collisions
crash_by_cs.head(15)
# Out:
#            FIPS  Total Collision Count
# 0   06037226002                     72
# 1   06037980024                     67
# 2   06037241202                     47
# 3   06037106510                     38
# 4   06037241001                     34
# 5   06037296600                     31
# 6   06037238400                     30
# 7   06037206031                     28
# 8   06037191000                     28
# 9   06037109100                     28
# 10  06037238200                     28
# 11  06037119002                     27
# 12  06037207710                     27
# 13  06037117303                     27
# 14  06037141500                     26

# %%
# descriptive stats for pedestian collisions. On average each census tract has had 11 pedestrian collision.
crash_by_cs['Total Collision Count'].describe()
# Out:
# count    1148.000000
# mean        7.082753
# std         6.725347
# min         1.000000
# 25%         2.000000
# 50%         5.000000
# 75%        10.000000
# max        72.000000
# Name: Total Collision Count, dtype: float64

# %%
# merging census tracts with pedestrian collisions 
la_city=la_city.merge(crash_by_cs,on='FIPS')

# %%
# verifying that both dataframes merged together
la_city.head(10)
# Out:
#           FIPS  Total Population  \
# 0  06037101110              4283
# 1  06037101122              3405
# 2  06037101210              6347
# 3  06037101220              3702
# 4  06037101300              3884
# 5  06037101400              3458
# 6  06037102103              1763
# 7  06037102104              3721
# 8  06037102105              1905
# 9  06037102107              4349
#
#                                             geometry  Total Collision Count
# 0  POLYGON ((-13168864.246 4064201.311, -13168757...                      3
# 1  POLYGON ((-13166582.527 4063754.258, -13166586...                      1
# 2  POLYGON ((-13167528.967 4063214.44, -13167528....                      6
# 3  POLYGON ((-13167423.881 4063213.632, -13167369...                      2
# 4  POLYGON ((-13165229.103 4062741.029, -13165229...                      7
# 5  POLYGON ((-13169034.788 4063225.626, -13168864...                     15
# 6  POLYGON ((-13173921.826 4059171.99, -13173936....                      7
# 7  POLYGON ((-13173332.61 4058687.307, -13173367....                      1
# 8  POLYGON ((-13173883.427 4056571.41, -13173900....                      4
# 9  POLYGON ((-13172435.269 4063723.845, -13172429...                     19

# %%
# new column "killed_per_1000" - the crash/killed rate 
la_city['collision_per_1000'] = la_city['Total Collision Count']/la_city['Total Population']*1000

# %%
# seeing the location of the top 10 places folks are killed 
fig,ax = plt.subplots(figsize=(12,12))
la_city.sort_values(by='collision_per_1000',ascending=False)[:15].plot(ax=ax,
                                                                 color='red',
                                                                 edgecolor='white',
                                                                 alpha=0.5)


# title
ax.set_title('Top 15 Census Tracts of Collisions per 1000 people in Los Angeles, 2015 - 2019',fontsize=15,pad=20)

# no axis
ax.axis('off')

# add a basemap
ctx.add_basemap(ax, zoom=14, source=ctx.providers.CartoDB.Positron)

# %%
sorted_la_city = la_city.sort_values(by='collision_per_1000', ascending=False)

# %%
#this are the census tracts with most collisions per 1,000
sorted_la_city.head(15)
# Out:
#              FIPS  Total Population  \
# 1146  06037980024               223
# 702   06037226002              1820
# 1147  06037980031              1175
# 534   06037206050              2031
# 407   06037189702              2201
# 542   06037207400              1539
# 66    06037109100              2797
# 421   06037190700              2685
# 338   06037141500              2982
# 165   06037122122              2728
# 693   06037224020              2733
# 701   06037226001              2615
# 813   06037241202              5776
# 808   06037241001              4197
# 692   06037224010              2845
#
#                                                geometry  \
# 1146  POLYGON ((-13192455.041 4053888.365, -13192239...
# 702   POLYGON ((-13162261.931 4033499.971, -13162283...
# 1147  MULTIPOLYGON (((-13163010.093 3997122.001, -13...
# 534   POLYGON ((-13160021.752 4034590.969, -13159918...
# 407   POLYGON ((-13173082.445 4043932.149, -13173071...
# 542   POLYGON ((-13162761.548 4036500.813, -13162689...
# 66    POLYGON ((-13186383.952 4066372.062, -13186374...
# 421   POLYGON ((-13172806.033 4042449.604, -13172711...
# 338   POLYGON ((-13187929.911 4048761.079, -13187993...
# 165   POLYGON ((-13177087.205 4058861.678, -13177062...
# 693   POLYGON ((-13164642.616 4032982.265, -13164651...
# 701   POLYGON ((-13162332.499 4032100.982, -13162333...
# 813   POLYGON ((-13166847.139 4020515.632, -13166847...
# 808   POLYGON ((-13166187.792 4019542.885, -13165826...
# 692   POLYGON ((-13165535.084 4034261.677, -13165531...
#
#       Total Collision Count  collision_per_1000
# 1146                     67          300.448430
# 702                      72           39.560440
# 1147                     14           11.914894
# 534                      23           11.324471
# 407                      24           10.904134
# 542                      16           10.396361
# 66                       28           10.010726
# 421                      25            9.310987
# 338                      26            8.718981
# 165                      23            8.431085
# 693                      23            8.415660
# 701                      22            8.413002
# 813                      47            8.137119
# 808                      34            8.101025
# 692                      23            8.084359

# %%
# identifying skew to determine mapping approach
la_city['collision_per_1000'].plot.hist(bins=25)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# using natural breaks for choropleth map 
fig,ax = plt.subplots(figsize=(15,15))

la_city.plot(ax=ax,  
        column='collision_per_1000',
        legend=True,
        alpha=0.8,    
        cmap='GnBu', 
        scheme='naturalbreaks',
        legend_kwds={'loc': 'center left', 'bbox_to_anchor': (1, 0.5)})

ax.axis('off')
ax.set_title('Collisions per 1000 people in Los Angeles, 2015 - 2019',fontsize=18,pad=20)
ctx.add_basemap(ax, zoom= 12,source=ctx.providers.CartoDB.Positron)

# %%
# creating interactive map of the same data presented above
la_city.explore(column='collision_per_1000', 
        legend=True,
        cmap='GnBu', 
        scheme='naturalbreaks',
        tiles='CartoDB positron',
        style_kwds={
            'weight':0.5,
            'color':'black',
            'opacity':0.5
        })
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4d385e139bff8abc59e9c40456b05d28 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4d385e139bff8abc59e9c40456b05d28&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4d385e139bff8abc59e9c40456b05d28 = L.map(
#                 &quot;map_4d385e139bff8abc59e9c40456b05d28&quot;,
#                 {
#                     center: [34.020479463335256, -118.41176783117436],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_4d385e139bff8abc59e9c40456b05d28);
#
#
#
#
#
#             var tile_layer_2a67154c939f82f25f36b1e87a9b6d6e = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2a67154c939f82f25f36b1e87a9b6d6e.addTo(map_4d385e139bff8abc59e9c40456b05d28);
#
#
#             map_4d385e139bff8abc59e9c40456b05d28.fitBounds(
#                 [[33.703652100434766, -118.66817777773213], [34.337306826235746, -118.15535788461659]],
#                 {}
#             );
#
#
#         function geo_json_6cfd55b016b4a0559d0647b40d12b484_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;1&quot;: case &quot;2&quot;: case &quot;3&quot;: case &quot;4&quot;: case &quot;7&quot;: case &quot;10&quot;: case &quot;11&quot;: case &quot;15&quot;: case &quot;16&quot;: case &quot;18&quot;: case &quot;19&quot;: case &quot;20&quot;: case &quot;27&quot;: case &quot;28&quot;: case &quot;29&quot;: case &quot;30&quot;: case &quot;31&quot;: case &quot;32&quot;: case &quot;33&quot;: case &quot;35&quot;: case &quot;36&quot;: case &quot;37&quot;: case &quot;38&quot;: case &quot;40&quot;: case &quot;43&quot;: case &quot;44&quot;: case &quot;45&quot;: case &quot;46&quot;: case &quot;48&quot;: case &quot;51&quot;: case &quot;54&quot;: case &quot;56&quot;: case &quot;57&quot;: case &quot;58&quot;: case &quot;59&quot;: case &quot;62&quot;: case &quot;63&quot;: case &quot;64&quot;: case &quot;65&quot;: case &quot;67&quot;: case &quot;70&quot;: case &quot;71&quot;: case &quot;72&quot;: case &quot;75&quot;: case &quot;76&quot;: case &quot;77&quot;: case &quot;78&quot;: case &quot;79&quot;: case &quot;80&quot;: case &quot;81&quot;: case &quot;82&quot;: case &quot;83&quot;: case &quot;84&quot;: case &quot;86&quot;: case &quot;88&quot;: case &quot;92&quot;: case &quot;94&quot;: case &quot;98&quot;: case &quot;105&quot;: case &quot;106&quot;: case &quot;108&quot;: case &quot;110&quot;: case &quot;111&quot;: case &quot;113&quot;: case &quot;114&quot;: case &quot;116&quot;: case &quot;117&quot;: case &quot;121&quot;: case &quot;122&quot;: case &quot;124&quot;: case &quot;125&quot;: case &quot;126&quot;: case &quot;129&quot;: case &quot;131&quot;: case &quot;132&quot;: case &quot;133&quot;: case &quot;135&quot;: case &quot;136&quot;: case &quot;137&quot;: case &quot;138&quot;: case &quot;139&quot;: case &quot;140&quot;: case &quot;141&quot;: case &quot;142&quot;: case &quot;143&quot;: case &quot;146&quot;: case &quot;147&quot;: case &quot;148&quot;: case &quot;149&quot;: case &quot;150&quot;: case &quot;152&quot;: case &quot;153&quot;: case &quot;157&quot;: case &quot;159&quot;: case &quot;163&quot;: case &quot;164&quot;: case &quot;167&quot;: case &quot;168&quot;: case &quot;169&quot;: case &quot;170&quot;: case &quot;172&quot;: case &quot;174&quot;: case &quot;175&quot;: case &quot;177&quot;: case &quot;178&quot;: case &quot;180&quot;: case &quot;182&quot;: case &quot;185&quot;: case &quot;187&quot;: case &quot;189&quot;: case &quot;190&quot;: case &quot;191&quot;: case &quot;193&quot;: case &quot;195&quot;: case &quot;196&quot;: case &quot;197&quot;: case &quot;198&quot;: case &quot;199&quot;: case &quot;200&quot;: case &quot;201&quot;: case &quot;203&quot;: case &quot;204&quot;: case &quot;205&quot;: case &quot;208&quot;: case &quot;209&quot;: case &quot;210&quot;: case &quot;211&quot;: case &quot;212&quot;: case &quot;214&quot;: case &quot;216&quot;: case &quot;218&quot;: case &quot;221&quot;: case &quot;223&quot;: case &quot;224&quot;: case &quot;225&qu

# %%
# calculating spatial weight 
wq =  lps.weights.KNN.from_dataframe(la_city,k=8)

# %%
# row standardization
wq.transform = 'r'

# %%
# spatial lag
la_city['collision_per_1000_lag']=lps.weights.lag_spatial(wq, la_city['collision_per_1000'])

# %%
# checking data
la_city.head(10)
# Out:
#           FIPS  Total Population  \
# 0  06037101110              4283
# 1  06037101122              3405
# 2  06037101210              6347
# 3  06037101220              3702
# 4  06037101300              3884
# 5  06037101400              3458
# 6  06037102103              1763
# 7  06037102104              3721
# 8  06037102105              1905
# 9  06037102107              4349
#
#                                             geometry  Total Collision Count  \
# 0  POLYGON ((-13168864.246 4064201.311, -13168757...                      3
# 1  POLYGON ((-13166582.527 4063754.258, -13166586...                      1
# 2  POLYGON ((-13167528.967 4063214.44, -13167528....                      6
# 3  POLYGON ((-13167423.881 4063213.632, -13167369...                      2
# 4  POLYGON ((-13165229.103 4062741.029, -13165229...                      7
# 5  POLYGON ((-13169034.788 4063225.626, -13168864...                     15
# 6  POLYGON ((-13173921.826 4059171.99, -13173936....                      7
# 7  POLYGON ((-13173332.61 4058687.307, -13173367....                      1
# 8  POLYGON ((-13173883.427 4056571.41, -13173900....                      4
# 9  POLYGON ((-13172435.269 4063723.845, -13172429...                     19
#
#    collision_per_1000  collision_per_1000_lag
# 0            0.700444                1.561742
# 1            0.293686                1.612587
# 2            0.945329                1.531132
# 3            0.540249                1.130783
# 4            1.802266                0.915239
# 5            4.337767                1.024994
# 6            3.970505                2.033998
# 7            0.268745                1.481294
# 8            2.099738                1.152552
# 9            4.368820                2.194049

# %%
# calculating the difference between between killed_per_1000 and the spatial lag ; and sorting the data
la_city['collision_lag_diff'] = la_city['collision_per_1000'] - la_city['collision_per_1000_lag']
la_city.sort_values(by='collision_lag_diff')
# Out:
#              FIPS  Total Population  \
# 261   06037132101              4645
# 224   06037127605              4329
# 325   06037139701              5320
# 324   06037139600              5060
# 546   06037207900              7162
# ...           ...               ...
# 534   06037206050              2031
# 407   06037189702              2201
# 1147  06037980031              1175
# 702   06037226002              1820
# 1146  06037980024               223
#
#                                                geometry  \
# 261   POLYGON ((-13190512.062 4054867.417, -13190374...
# 224   POLYGON ((-13189783.028 4054868.219, -13189540...
# 325   POLYGON ((-13189536.919 4051003.355, -13189537...
# 324   POLYGON ((-13191481.566 4051699.359, -13191481...
# 546   POLYGON ((-13164323.023 4034580.051, -13164263...
# ...                                                 ...
# 534   POLYGON ((-13160021.752 4034590.969, -13159918...
# 407   POLYGON ((-13173082.445 4043932.149, -13173071...
# 1147  MULTIPOLYGON (((-13163010.093 3997122.001, -13...
# 702   POLYGON ((-13162261.931 4033499.971, -13162283...
# 1146  POLYGON ((-13192455.041 4053888.365, -13192239...
#
#       Total Collision Count  collision_per_1000  collision_per_1000_lag  \
# 261                       1            0.215285               39.358227
# 224                       1            0.231000               39.077705
# 325                       8            1.503759               39.500170
# 324                       5            0.988142               38.791087
# 546                      21            2.932142                8.731450
# ...                     ...                 ...                     ...
# 534                      23           11.324471                2.414294
# 407                      24           10.904134                1.939885
# 1147                     14           11.914894                1.871836
# 702                      72           39.560440                3.321495
# 1146                     67          300.448430                1.318996
#
#       collision_lag_diff
# 261           -39.142941
# 224           -38.846705
# 325           -37.996411
# 324           -37.802945
# 546            -5.799308
# ...                  ...
# 534             8.910177
# 407             8.964249
# 1147           10.043057
# 702            36.238945
# 1146          299.129434
#
# [1148 rows x 7 columns]

# %%
# FIPS with the highest negative difference ; look at areas and try to identify potential factors
la_city_donut = la_city.sort_values(by='collision_lag_diff').head(1)
la_city_donut
# Out:
#             FIPS  Total Population  \
# 261  06037132101              4645
#
#                                               geometry  Total Collision Count  \
# 261  POLYGON ((-13190512.062 4054867.417, -13190374...                      1
#
#      collision_per_1000  collision_per_1000_lag  collision_lag_diff
# 261            0.215285               39.358227          -39.142941

# %%
# FIPS with the highest positive difference 
la_city_diamond = la_city.sort_values(by='collision_lag_diff').tail(1)
la_city_diamond
# Out:
#              FIPS  Total Population  \
# 1146  06037980024               223
#
#                                                geometry  \
# 1146  POLYGON ((-13192455.041 4053888.365, -13192239...
#
#       Total Collision Count  collision_per_1000  collision_per_1000_lag  \
# 1146                     67           300.44843                1.318996
#
#       collision_lag_diff
# 1146          299.129434

# %%
# creating a map using satellite imagery, this image describes the census tract that has a low collision count while surrounding tracts have higher collision counts. 
la_city_donut.explore(tiles='https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}',
                  attr= 'Tiles &copy; Esri &mdash; Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f5a6e9ad32fa14c6c6ca073ef75ee154 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f5a6e9ad32fa14c6c6ca073ef75ee154&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f5a6e9ad32fa14c6c6ca073ef75ee154 = L.map(
#                 &quot;map_f5a6e9ad32fa14c6c6ca073ef75ee154&quot;,
#                 {
#                     center: [34.19026314665592, -118.4956569466753],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_f5a6e9ad32fa14c6c6ca073ef75ee154);
#
#
#
#
#
#             var tile_layer_58153e401a47ef9f82abfd0965c8e293 = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Tiles \u0026copy; Esri \u0026mdash; Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_58153e401a47ef9f82abfd0965c8e293.addTo(map_f5a6e9ad32fa14c6c6ca073ef75ee154);
#
#
#             map_f5a6e9ad32fa14c6c6ca073ef75ee154.fitBounds(
#                 [[34.18662766887959, -118.50111794508348], [34.193898624432265, -118.4901959482671]],
#                 {}
#             );
#
#
#         function geo_json_3363972f00054e6b9f31b21cf03176d5_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_3363972f00054e6b9f31b21cf03176d5_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_3363972f00054e6b9f31b21cf03176d5_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_3363972f00054e6b9f31b21cf03176d5_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_3363972f00054e6b9f31b21cf03176d5_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_3363972f00054e6b9f31b21cf03176d5.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_3363972f00054e6b9f31b21cf03176d5_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_3363972f00054e6b9f31b21cf03176d5 = L.geoJson(null, {
#                 onEachFeature: geo_json_3363972f00054e6b9f31b21cf03176d5_onEachFeature,
#
#                 style: geo_json_3363972f00054e6b9f31b21cf03176d5_styler,
#                 pointToLayer: geo_json_3363972f00054e6b9f31b21cf03176d5_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_3363972f00054e6b9f31b21cf03176d5_add (data) {
#             geo_json_3363972f00054e6b9f31b21cf03176d5
#                 .addData(data);
#         }
#             geo_json_3363972f00054e6b9f31b21cf03176d5_add({&quot;bbox&quot;: [-118.50111794508348, 34.18662766887959, -118.4901959482671, 34.193898624432265], &quot;features&quot;: [{&quot;bbox&quot;: [-118.50111794508348, 34.18662766887959, -118.4901959482671, 34.193898624432265], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-118.49238591079906, 34.19389663887254], [-118.49115190409883, 34.193897630287104], [-118.49020290071392, 34.193898624432265], [-118.49019992404706, 34.190271615341004], [-118.49019893140725, 34.18919861216041], [-118.49019793674408, 34.188396610021634], [-118.49019694198266, 34.18761660798347], [-118.4901959482671, 34.18663560535604], [-118.4923799588

# %%
# creating a map using satellite imagery, this image describes the census tract that has a high collision count while surrounding tracts have a lower collision counts. 
la_city_diamond.explore(tiles='https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}',
                  attr= 'Tiles &copy; Esri &mdash; Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c14a16589e3bae0e8b871a6baa57b74f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c14a16589e3bae0e8b871a6baa57b74f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c14a16589e3bae0e8b871a6baa57b74f = L.map(
#                 &quot;map_c14a16589e3bae0e8b871a6baa57b74f&quot;,
#                 {
#                     center: [34.17332593626074, -118.49300645741761],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_c14a16589e3bae0e8b871a6baa57b74f);
#
#
#
#
#
#             var tile_layer_84f524915a1dd3ccbcdf7142b247ba48 = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Tiles \u0026copy; Esri \u0026mdash; Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_84f524915a1dd3ccbcdf7142b247ba48.addTo(map_c14a16589e3bae0e8b871a6baa57b74f);
#
#
#             map_c14a16589e3bae0e8b871a6baa57b74f.fitBounds(
#                 [[34.160006374012106, -118.51849599960163], [34.186645498509364, -118.46751691523357]],
#                 {}
#             );
#
#
#         function geo_json_f0562778093f18673454751b84329bdb_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_f0562778093f18673454751b84329bdb_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_f0562778093f18673454751b84329bdb_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_f0562778093f18673454751b84329bdb_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_f0562778093f18673454751b84329bdb_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_f0562778093f18673454751b84329bdb.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_f0562778093f18673454751b84329bdb_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_f0562778093f18673454751b84329bdb = L.geoJson(null, {
#                 onEachFeature: geo_json_f0562778093f18673454751b84329bdb_onEachFeature,
#
#                 style: geo_json_f0562778093f18673454751b84329bdb_styler,
#                 pointToLayer: geo_json_f0562778093f18673454751b84329bdb_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_f0562778093f18673454751b84329bdb_add (data) {
#             geo_json_f0562778093f18673454751b84329bdb
#                 .addData(data);
#         }
#             geo_json_f0562778093f18673454751b84329bdb_add({&quot;bbox&quot;: [-118.51849599960163, 34.160006374012106, -118.46751691523357, 34.186645498509364], &quot;features&quot;: [{&quot;bbox&quot;: [-118.51849599960163, 34.160006374012106, -118.46751691523357, 34.186645498509364], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-118.50983998556222, 34.1866216419818], [-118.50790698766993, 34.18662264755564], [-118.50400999358334, 34.18662566017825], [-118.50111199724358, 34.18662766887959], [-118.49914599365516, 34.186629666621], [-118.49773998594011, 34.18663065641824], [-118.49714598316852, 34.18663065260644], [-118.4923799588392, 34.18663462079753], [-118.4901959482

# %%
# spatial lag map - mapping the entire dataframe
fig, ax = plt.subplots(figsize=(15, 15))

la_city.plot(ax=ax,
         figsize=(15,15),
         column='collision_per_1000_lag',
         legend=True,
         alpha=0.8,
         cmap='GnBu',
         scheme='quantiles', 
         legend_kwds={'loc': 'center left', 'bbox_to_anchor': (1, 0.5)})

ax.axis('off')
ax.set_title('Collisions per 1000 people in Los Angeles (2015 - 2019)',fontsize=20,pad=20)

ctx.add_basemap(ax,zoom =12, source=ctx.providers.CartoDB.Positron)

# %%
# ploting both collisions per 1000 and lag 
fig, ax = plt.subplots(1, 2, figsize=(20, 12))

#ax[0] - map on the left 
la_city.plot(ax=ax[0], # this assigns the map to the left subplot
         column='collision_per_1000', 
         cmap='GnBu', 
         scheme='quantiles',
         k=5, 
         edgecolor='white', 
         linewidth=0, 
         alpha=0.75, 
           )


ax[0].axis("off")
ax[0].set_title("Collisions per 1000 people in Los Angeles (2015 - 2019)")

# ax[1] - map on the right 
la_city.plot(ax=ax[1], 
         column='collision_per_1000_lag', 
         cmap='GnBu', 
         scheme='quantiles',
         k=5, 
         edgecolor='white', 
         linewidth=0, 
         alpha=0.75
           )

ax[1].axis("off")
ax[1].set_title("Collisions per 1000 people in Los Angeles (2015 - 2019) - Spatial Lag")

plt.show()

# %%
# quantifying the degree of spatial correlation, output was positive meaning that high collision tracts are located near other high collision tracts and vise versa
y = la_city.collision_per_1000
moran = Moran(y, wq)
moran.I
# Out:
# np.float64(0.0023877045376720233)

# %%
# creating scatterplot
fig, ax = moran_scatterplot(moran, aspect_equal=True)
plt.show()

# %%
# dcreating reference distribution
plot_moran_simulation(moran,aspect_equal=False)
# Out:
# (<Figure size 700x700 with 1 Axes>,
#  <Axes: title={'center': 'Reference Distribution'}, xlabel='Moran I: 0.0', ylabel='Density'>)

# %%
# p-value , 99% confidence, we are 99% confient that there is statistically significantly spatial clustering with collisions per 1,000 residents in the City of LA from 2015-2019. 
moran.p_sim
# Out:
# np.float64(0.161)

# %%
# moran local scatterplot
lisa = esda.moran.Moran_Local(y, wq)

# %%
# plot 
fig,ax = plt.subplots(figsize=(20,15))

moran_scatterplot(lisa, ax=ax, p=0.05)
ax.set_xlabel("Collisions")
ax.set_ylabel('Spatial Lag of Collisions')

# test #1 
# nedd to play with the number more?
plt.text(1.95, 0.5, "HH", fontsize=25) 
plt.text(1.95, -1, "HL", fontsize=25)
plt.text(-2, 1, "LH", fontsize=25)
plt.text(-1, -1, "LL", fontsize=25)
plt.show()

# %%
# mapping 
fig, ax = plt.subplots(figsize=(14,12))
lisa_cluster(lisa, la_city, p=0.05, ax=ax) 
plt.show()

# %%
# create maps with different p-values
# create the 1x2 subplots
fig, ax = plt.subplots(1, 2, figsize=(20, 12))

# regular count map on the left
lisa_cluster(lisa,la_city, p=0.05, ax=ax[0])

ax[0].axis("off")
ax[0].set_title("P-value: 0.05")

# spatial lag map on the right
lisa_cluster(lisa, la_city, p=0.01, ax=ax[1])
ax[1].axis("off")
ax[1].set_title("P-value: 0.01")

plt.show()

# %% [markdown]
# ## Team Roles
#
# ### Emily
#
# Conducted spatial analysis for fatal pedestrian and bicycle collisions in the City of LA
#
# ### Gema
#
# Conducted spatial analysis for pedestrian in the City of LA
#
# ### Veronica
# Conducted spatial analysis for fatal bicycle collisions in the City of LA
